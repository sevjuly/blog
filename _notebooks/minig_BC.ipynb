# %% [markdown]
# ### Table of Contents in this notebook
#
# * [Chapter 1](#chapter1)
#     * [Section 1.1](#section_1_1)
#     * [Section 1.2](sSection_1_2)
#         * [Section 1.2.1](#section_1_2_1)
#         * [Section 1.2.2](#section_1_2_2)
#         * [Section 1.2.3](#section_1_2_3)
# * [Chapter 2](#chapter2)
#     * [Section 2.1](#section_2_1)
#     * [Section 2.2](#section_2_2)

# %% [markdown]
# # "데이터 마이닝 보고서"
# > "Awesome summary"
#
# - toc:true- branch: master
# - badges: true
# - comments: true
# - author: sunmin park
# - categories: [fastpages, jupyter]

# %% [markdown]
# ### Chapter 1 <a class="anchor" id="chapter1"></a>

# %% [markdown]
# # 분석 배경 및 동기 , 목적

# %% [markdown]
# 이번에 선정한 주제는 포스트 코로나 시기의 BC카드 사용 지표를 가지고 시각화를 해보는 것이다
# 2020년도부터 시작된 코로나 상황에 어떤 분야의 소비 변화가 큰지, 가장 소비가 많이 되는 부분은 어느 부분이었는지에 대한 궁금증을 해결하고 알아보기 위해 이 주제를 선정하게 되었다.
# 분야별 시각화를 통해 변화 상태를 알아보고 확진자 수가 사람들의 소비에 어떤 영향을 미치는 지를 알아보았다.

# %%
#사용한 패키지들이다.
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Parksunmin\OneDrive\바탕 화면\데이터 마이닝\minig_BC.ipynb Cell 5' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Parksunmin/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D/minig_BC.ipynb#ch0000000?line=0'>1</a> #사용한 패키지들이다.
#       <a href='vscode-notebook-cell:/c%3A/Users/Parksunmin/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D/minig_BC.ipynb#ch0000000?line=1'>2</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Parksunmin/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D/minig_BC.ipynb#ch0000000?line=3'>4</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Parksunmin/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D/minig_BC.ipynb#ch0000000?line=5'>6</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/Parksunmin/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%A7%88%EC%9D%B4%EB%8B%9D/minig_BC.ipynb#ch0000000?line=7'>8</a> import seaborn as sns
#
# File c:\Users\Parksunmin\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\__init__.py:135, in <module>
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=116'>117</a> from pandas.core.computation.api import eval
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=118'>119</a> from pandas.core.reshape.api import (
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=119'>120</a>     concat,
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=120'>121</a>     lreshape,
#    (...)
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=131'>132</a>     qcut,
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=132'>133</a> )
# --> <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=134'>135</a> from pandas import api, arrays, errors, io, plotting, testing, tseries
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=135'>136</a> from pandas.util._print_versions import show_versions
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=137'>138</a> from pandas.io.api import (
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=138'>139</a>     # excel
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=139'>140</a>     ExcelFile,
#    (...)
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=167'>168</a>     read_spss,
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/__init__.py?line=168'>169</a> )
#
# File c:\Users\Parksunmin\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\testing.py:6, in <module>
#       <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=0'>1</a> """
#       <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=1'>2</a> Public testing utility functions.
#       <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=2'>3</a> """
# ----> <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=5'>6</a> from pandas._testing import (
#       <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=6'>7</a>     assert_extension_array_equal,
#       <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=7'>8</a>     assert_frame_equal,
#       <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=8'>9</a>     assert_index_equal,
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=9'>10</a>     assert_series_equal,
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=10'>11</a> )
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=12'>13</a> __all__ = [
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=13'>14</a>     "assert_extension_array_equal",
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=14'>15</a>     "assert_frame_equal",
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=15'>16</a>     "assert_series_equal",
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=16'>17</a>     "assert_index_equal",
#      <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/testing.py?line=17'>18</a> ]
#
# File c:\Users\Parksunmin\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\_testing\__init__.py:979, in <module>
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=973'>974</a>     import pytest
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=975'>976</a>     return pytest.raises(expected_exception, match=None)  # noqa: PDF010
# --> <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=978'>979</a> cython_table = pd.core.common._cython_table.items()
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=981'>982</a> def get_cython_table_params(ndframe, func_names_and_expected):
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=982'>983</a>     """
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=983'>984</a>     Combine frame, functions from com._cython_table
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=984'>985</a>     keys and expected result.
#    (...)
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=996'>997</a>         List of three items (DataFrame, function, expected result)
#     <a href='file:///c%3A/Users/Parksunmin/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/_testing/__init__.py?line=997'>998</a>     """
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %% [markdown]
# #### Section 1.1 <a class="anchor" id="section_1_1"></a>

# %%
a = pd.read_csv('data_bc/2020_01.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
b = pd.read_csv('data_bc/2020_02.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
c = pd.read_csv('data_bc/2020_03.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
d = pd.read_csv('data_bc/2020_04.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
e = pd.read_csv('data_bc/2020_05.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
f = pd.read_csv('data_bc/2020_06.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
g = pd.read_csv('data_bc/2020_07.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
h = pd.read_csv('data_bc/2020_08.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
i = pd.read_csv('data_bc/2020_09.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
j = pd.read_csv('data_bc/2020_10.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
k = pd.read_csv('data_bc/2020_11.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
l = pd.read_csv('data_bc/2020_12.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
year_2020 = pd.concat([a,b,c,d,e,f,g,h,i,j,k,l])

# 월별 csv로 만들어져있는 파일들을 연도별로 합쳐서 만들었다. -2020년 , year_2020 이라는 변수명으로 저장하였다
# Out:
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1409844361.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   a = pd.read_csv('data_bc/2020_01.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1409844361.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   d = pd.read_csv('data_bc/2020_04.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1409844361.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   f = pd.read_csv('data_bc/2020_06.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1409844361.py:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   g = pd.read_csv('data_bc/2020_07.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1409844361.py:11: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   k = pd.read_csv('data_bc/2020_11.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])

# %%
ab =  pd.read_csv('data_bc/2021_01.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
bc =  pd.read_csv('data_bc/2021_02.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
cd =  pd.read_csv('data_bc/2021_03.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
de =  pd.read_csv('data_bc/2021_04.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
ef =  pd.read_csv('data_bc/2021_05.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
fg =  pd.read_csv('data_bc/2021_06.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
gh =  pd.read_csv('data_bc/2021_07.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
hi =  pd.read_csv('data_bc/2021_08.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
ij =  pd.read_csv('data_bc/2021_09.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
ik =  pd.read_csv('data_bc/2021_10.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
kl =  pd.read_csv('data_bc/2021_11.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
lm =  pd.read_csv('data_bc/2021_12.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
year_2021 = pd.concat([ ab,bc,cd,de,ef,fg,gh,hi,ij,ik,kl,lm])

#월별 csv 파일 - 2021년 , year_2021 이라는 변수명으로 저장하였다

# %%
a =  pd.read_csv('data_bc/2022_01.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
b =  pd.read_csv('data_bc/2022_02.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
c =  pd.read_csv('data_bc/2022_03.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
d =  pd.read_csv('data_bc/2022_04.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
year_2022 = pd.concat([a,b,c,d])

#월별 csv 파일 -2022년 , year_2022 라는 변수명으로 저장하였고 2022년도의 데이터는 4월까지로 구성되어있다.

# %%
year_2020.shape #각 데이터 별 행렬개수를 알아본다_2020
# Out:
# (1068701, 4)

# %%
year_2021.shape #각 데이터 별 행렬개수를 알아본다_2021

# %%
year_2022.shape #각 데이터 별 행렬개수를 알아본다_2022

# %% [markdown]
# ## 데이터별 head&tail

# %%
year_2020.head()
# Out:
#        년월    대분류      소분류 나이대  성별코드  지역 지역_2  금액지표  건수지표
# 0  202001  보건/위생      사우나  30     1  강원  강릉시   160   133
# 1  202001  보건/위생      사우나  80     1  강원  강릉시    99   121
# 2  202001  보건/위생  기타대인서비스  30     1  강원  강릉시    61   113
# 3  202001   일반음식     일식회집  60     1  강원  강릉시    93   102
# 4  202001   일반음식     일식회집  60     2  강원  강릉시   105    96

# %%
year_2020.tail()
# Out:
#             년월 대분류    소분류 나이대  성별코드  지역 지역_2  금액지표  건수지표
# 290956  202112  기타  기계 공구  60     1  충북  충주시    94    84
# 290957  202112  기타  비 영 리  40     2  충북  충주시   151   273
# 290958  202112  기타  기타전문점  20     1  충북  충주시   461   750
# 290959  202112  기타  기타전문점  50     1  충북  충주시    33    86
# 290960  202112  기타  기타전문점  60     1  충북  충주시    78    74

# %%
year_2021.head()

# %% [markdown]
# year_2021.tail()

# %%
year_2022.head()

# %%
year_2022.tail()

# %% [markdown]
# ## 대분류 종류 확인하기

# %%
year_2020["대분류"].unique()
year_2021["대분류"].unique()
year_2022["대분류"].unique()
# Out:
# array(['보건/위생', '일반음식', '휴게', '유흥주점(음식)', '단란주점(음식)', '음식료품', '건강식품',
#        '건축/자재', '용역서비스', '수리서비스', '회원제형태업소', '농업', '기타', '숙박업',
#        '자동차정비/유지', '의료기관', '사무/통신기기', '보험', '문화/취미', '가구', '가전제품', '연료판매',
#        '유통업영리', '유통업비영리', '의류', '직물', '신변잡화', '서적/문구', '학원', '레져용품',
#        '레져업소', '주방용품', '광학제품', '여행업', '자동차판매', '당사통신판매업소'], dtype=object)

# %% [markdown]
# #### Section 1.2 <a class="anchor" id="section_1_2"></a>

# %% [markdown]
# 각 년도별로 대분류 중에서 시각화에 필요한 분야들을 추출하였다. 총 34가지에서 10가지로 추려내었다.
# 10 가지는 '보건/위생', '일반음식', '유흥주점(음식)', '단란주점(음식)', '숙박업', '의료기관', '사무/통신기기','보험', '문화/취미', '여행업' 이다.

# %%
year_2020 =year_2020[(year_2020["대분류"]=="일반음식") | (year_2020["대분류"]=="유흥주점(음식)") | (year_2020["대분류"]=="단란주점(음식)") | (year_2020["대분류"]=="숙박업")|(year_2020["대분류"]=="여행업")| (year_2020["대분류"]=="문화/취미") | (year_2020["대분류"]=="사무/통신기기")| (year_2020["대분류"]=="보건/위생") | (year_2020["대분류"]=="의료기관") | (year_2020["대분류"]=="보험")]

# %%
year_2021 =year_2021[(year_2021["대분류"]=="일반음식") | (year_2021["대분류"]=="유흥주점(음식)") | (year_2021["대분류"]=="단란주점(음식)") | (year_2021["대분류"]=="숙박업")|(year_2021["대분류"]=="여행업")| (year_2021["대분류"]=="문화/취미") | (year_2021["대분류"]=="사무/통신기기")| (year_2021["대분류"]=="보건/위생") | (year_2021["대분류"]=="의료기관") | (year_2021["대분류"]=="보험")]

# %%
year_2022 =year_2022[(year_2022["대분류"]=="일반음식") | (year_2022["대분류"]=="유흥주점(음식)") | (year_2022["대분류"]=="단란주점(음식)") | (year_2022["대분류"]=="숙박업")|(year_2022["대분류"]=="여행업")| (year_2022["대분류"]=="문화/취미") | (year_2022["대분류"]=="사무/통신기기")| (year_2022["대분류"]=="보건/위생") | (year_2022["대분류"]=="의료기관") | (year_2022["대분류"]=="보험")]

# %%
year_2020["대분류"].unique()
# Out:
# array(['보건/위생', '일반음식', '유흥주점(음식)', '단란주점(음식)', '숙박업', '의료기관', '사무/통신기기',
#        '보험', '문화/취미', '여행업'], dtype=object)

# %% [markdown]
# ## 필요없는 열 정리하기

# %% [markdown]
# 가장 중요하게 사용한 열은 년월, 대분류, 금액지표와 건수지표였다. 금액지표와 건수지표를 둘 다 활용하면 좋았을 것 같으나, 시각화에는 건수지표만을 사용하였다

# %%
year_2020 = year_2020.drop(["소분류","지역","지역_2","성별코드","나이대"],axis=1)

# %%
year_2021 = year_2021.drop(["소분류","지역","지역_2","성별코드","나이대"],axis=1)

# %%
year_2022 = year_2022.drop(["소분류","지역","지역_2","성별코드","나이대"],axis=1)

# %%
year_2020 # drop을 시킨 후의 결과가 잘 나왔는 지 확인해보았다
# Out:
#             년월       대분류  금액지표  건수지표
# 0       202001     보건/위생   160   133
# 1       202001     보건/위생    99   121
# 2       202001     보건/위생    61   113
# 3       202001      일반음식    93   102
# 4       202001      일반음식   105    96
# ...        ...       ...   ...   ...
# 277539  202012      일반음식    62    64
# 277545  202012      일반음식     7     4
# 277546  202012  유흥주점(음식)    18     6
# 277547  202012  단란주점(음식)     3     5
# 277548  202012  단란주점(음식)    10    13
#
# [1068701 rows x 4 columns]

# %%
year_2020["대분류"].unique() #필요하다고 느낀 분야들이 제대로 들어있는지를 다시 한 번 확인하였다
# Out:
# array(['보건/위생', '일반음식', '유흥주점(음식)', '단란주점(음식)', '숙박업', '의료기관', '사무/통신기기',
#        '보험', '문화/취미', '여행업'], dtype=object)

# %% [markdown]
# ## 종류별 그래프

# %% [markdown]
# 건수 지표를 이용하여 시간의 흐름에 따라 소비의 흐름이 어떻게 변하는 지를 보기 위해 그래프를 그렸다.
# 변화를 관찰하기엔 꺾은선 그래프가 적절하다고 판단되어 꺾은 선 그래프를 사용하였다.
# 2020년도별 , 2021년도별, 2022년도별로 같은 분야끼리 같은 색상으로 통일하였다. 또 연도별로 데이터의 용량 문제로 따로 따로 변수를 만들어서 시각화를 한 것이기에 분야별로 Y축의 범위를 똑같이 지정해주었다

# %% [markdown]
# #보건위생

# %%
a= year_2020[year_2020['대분류']=='보건/위생']
clean=a.groupby('년월')['건수지표'].sum()
clean.plot(color ="red",linewidth =3.0)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("보건/위생")
plt.show()

# %%
a= year_2021[year_2021['대분류']=='보건/위생']

clean= a.groupby('년월')['건수지표'].sum()
clean

clean.plot(color ="red",linewidth =3.0)
plt.ylim(2200000, 3400000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("보건/위생")
plt.show()

#2021년도

# %%
a= year_2022[year_2022['대분류']=='보건/위생']

clean= a.groupby('년월')['건수지표'].sum()
clean

clean.plot(color ="red",linewidth =3.0)
plt.ylim(2200000, 3400000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("보건/위생")
plt.show()

#2022년도

# %% [markdown]
# #일반음식

# %%
b= year_2020[year_2020['대분류']=='일반음식'] #일반 음식
food = b.groupby('년월')['건수지표'].sum()
food.plot(color ="orange",linewidth =3.0)
plt.ylim(3000000,7000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("일반음식")
plt.show()

# %%
b= year_2021[year_2021['대분류']=='일반음식']
b

food= b.groupby('년월')['건수지표'].sum()
food.plot(color ="orange",linewidth =3.0)
plt.ylim(3000000,7000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("일반음식")
plt.show()

# 2021년도

# %%
b= year_2022[year_2022['대분류']=='일반음식']
b

food= b.groupby('년월')['건수지표'].sum()
food.plot(color ="orange",linewidth =3.0)
plt.ylim(3000000,7000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("일반음식")
plt.show()

#2022년도

# %% [markdown]
# #유흥주점 -단란주점과의 차이는 접객원을 두냐 안 두냐의 차이라고 한다

# %%
c= year_2020[year_2020['대분류']=='유흥주점(음식)']
wine = c.groupby('년월')['건수지표'].sum()
wine.plot(color ="yellow",linewidth =3.0)
plt.ylim(0,260000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("유흥주점(음식)")
plt.show()

# %%
c= year_2021[year_2021['대분류']=='유흥주점(음식)']
wine= c.groupby('년월')['건수지표'].sum()
wine.plot(color ="yellow",linewidth =3.0)
plt.ylim(0,260000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("유흥주점(음식)")
plt.show()

#2021년

# %%
c= year_2022[year_2022['대분류']=='유흥주점(음식)']
wine= c.groupby('년월')['건수지표'].sum()
wine.plot(color ="yellow",linewidth =3.0)
plt.ylim(0,260000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("유흥주점(음식)")
plt.show()

#2022년

# %% [markdown]
# #단란주점

# %%
d = year_2020[year_2020['대분류']=='단란주점(음식)']

wine_2 = d.groupby('년월')['건수지표'].sum()
wine_2.plot(color ="yellowgreen",linewidth =3.0)
plt.ylim(0, 250000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("단란주점(음식)")
plt.show()

# %%
d= year_2021[year_2021['대분류']=='단란주점(음식)']
wine_2= d.groupby('년월')['건수지표'].sum()
wine_2.plot(color ="yellowgreen",linewidth =3.0)
plt.ylim(0, 250000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("단란주점(음식)")
plt.show()

#2021년

# %%
d= year_2022[year_2022['대분류']=='단란주점(음식)']
wine_2= d.groupby('년월')['건수지표'].sum()
wine_2.plot(color ="yellowgreen",linewidth =3.0)
plt.ylim(0, 250000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("단란주점(음식)")
plt.show()

#2022년

# %% [markdown]
# #숙박업

# %%
e = year_2020[year_2020['대분류']=='숙박업']

house = e.groupby('년월')['건수지표'].sum()
house.plot(color ="darkgreen",linewidth =3.0)
plt.ylim(50000, 1300000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("숙박업")
plt.show()

# %%
e = year_2021[year_2021['대분류']=='숙박업']

house = e.groupby('년월')['건수지표'].sum()
house.plot(color ="darkgreen",linewidth =3.0)
plt.ylim(50000, 1300000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("숙박업")
plt.show()

#2021

# %%
e = year_2022[year_2022['대분류']=='숙박업']

house = e.groupby('년월')['건수지표'].sum()
house.plot(color ="darkgreen",linewidth =3.0)
plt.ylim(50000, 1300000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("숙박업")
plt.show()

#2022

# %% [markdown]
# #의료기관

# %%
f= year_2020[year_2020['대분류']=='의료기관']

hospital = f.groupby('년월')['건수지표'].sum()
hospital.plot(color ="skyblue",linewidth =3.0)
plt.ylim(7000000,10500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("의료기관")
plt.show()

# %%
f= year_2021[year_2021['대분류']=='의료기관']

hospital = f.groupby('년월')['건수지표'].sum()
hospital.plot(color ="skyblue",linewidth =3.0)
plt.ylim(7000000,10500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("의료기관")
plt.show()

#2021

# %%
f= year_2022[year_2022['대분류']=='의료기관']

hospital = f.groupby('년월')['건수지표'].sum()
hospital.plot(color ="skyblue",linewidth =3.0)
plt.ylim(7000000,10500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("의료기관")
plt.show()

#2022

# %% [markdown]
# #사무/통신기기

# %%
g = year_2020[year_2020['대분류']=='사무/통신기기']

tel = g.groupby('년월')['건수지표'].sum()
tel.plot(color ="darkblue",linewidth =3.0)
plt.ylim(1000000,5000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("사무/통신기기")
plt.show()

# %%
g = year_2021[year_2021['대분류']=='사무/통신기기']

tel = g.groupby('년월')['건수지표'].sum()
tel.plot(color ="darkblue",linewidth =3.0)
plt.ylim(1000000,5000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("사무/통신기기")
plt.show()

#2021

# %%
g = year_2022[year_2022['대분류']=='사무/통신기기']

tel = g.groupby('년월')['건수지표'].sum()
tel.plot(color ="darkblue",linewidth =3.0)
plt.ylim(1000000,5000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("사무/통신기기")
plt.show()

#2022

# %% [markdown]
# #여행업

# %%
h = year_2020[year_2020['대분류']=='여행업']

travel = h.groupby('년월')['건수지표'].sum()
travel.plot(color ="purple",linewidth =3.0)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("여행업")
plt.show()

# %%
h = year_2021[year_2021['대분류']=='여행업']

travel = h.groupby('년월')['건수지표'].sum()
travel.plot(color ="purple",linewidth =3.0)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("여행업")
plt.show()

#2021

# %%
h = year_2022[year_2022['대분류']=='여행업']

travel = h.groupby('년월')['건수지표'].sum()
travel.plot(color ="purple",linewidth =3.0)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("여행업")
plt.show()

#2022

# %% [markdown]
# #문화/취미

# %%
i = year_2020[year_2020['대분류']=='문화/취미']

hob = i.groupby('년월')['건수지표'].sum()
hob.plot(color ="pink",linewidth =3.0)
plt.ylim(2300000,8500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("문화/취미")
plt.show()

# %%
i = year_2021[year_2021['대분류']=='문화/취미']

hob = i.groupby('년월')['건수지표'].sum()
hob.plot(color ="pink",linewidth =3.0)
plt.ylim(2300000,8500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("문화/취미")
plt.show()

#2021

# %%
h = year_2022[year_2022['대분류']=='여행업']

travel = h.groupby('년월')['건수지표'].sum()
travel.plot(color ="purple",linewidth =3.0)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("여행업")
plt.show()

#2022

# %% [markdown]
# #보험

# %%
j = year_2020[year_2020['대분류']=='보험']

bo = j.groupby('년월')['건수지표'].sum()
bo.plot(color = "gray", linewidth=3.0) #색상 지정 / 선 굴기 지정
plt.ylim(7250000,9500000)
plt.ticklabel_format(style ='plain') #애를 쓰면 원래의 값이 나오고, 안 쓰면 간결하게 나온다.
plt.xlabel("년_월")
plt.ylabel("월별 건수 합")
plt.title("보험")
plt.show()

# %%
j = year_2021[year_2021['대분류']=='보험']

bo = j.groupby('년월')['건수지표'].sum()
bo.plot(color ="gray",linewidth =3.0)
plt.ylim(7250000,9500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("보험")
plt.show()

#2021

# %%
j = year_2022[year_2022['대분류']=='보험']

bo = j.groupby('년월')['건수지표'].sum()
bo.plot(color ="gray",linewidth =3.0)
plt.ylim(7250000,9500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("보험")
plt.show()

#2022

# %% [markdown]
# #### Section 2.1 <a class="anchor" id="section_2_1"></a>

# %% [markdown]
# 각 연도별로 그래프를 그려보았고 시간이 흐름에 따라 변화가 어떻게 일어나는지를 알아볼 수 있었다.
# 하지만 어떤 분야의 소비가 가장 많이 이루어지는지, 변화폭이 큰지를 알긴 어렵다는 한계점을 느꼈다.
# 그렇기에 각 연도의 월별, 분야별의 건수 지표의 합계를 구하여 comp라는 변수로 만들어주었다.

# %%
comp = pd.merge(left=clean, right = food, how ="inner",on ="년월")
comp = comp.merge(right = wine, how ="inner",on ="년월")
comp = comp.merge(right = wine_2, how ="inner",on ="년월")
comp = comp.merge(right = house, how ="inner",on ="년월")
comp = comp.merge(right = hospital, how ="inner",on ="년월")
comp = comp.merge(right = tel, how ="inner",on ="년월")
comp = comp.merge(right = travel, how ="inner",on ="년월")
comp = comp.merge(right = hob, how ="inner",on ="년월")
comp

# merge 속 들어있는 변수들은 모두 위의 꺾은선 그래프를 그릴 때 만들었던 변수들을 사용한 것이다.
# Out:
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1466163675.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'건수지표_x'} in the result is deprecated and will raise a MergeError in a future version.
#   comp = comp.merge(right = wine_2, how ="inner",on ="년월")
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1466163675.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'건수지표_x'} in the result is deprecated and will raise a MergeError in a future version.
#   comp = comp.merge(right = hospital, how ="inner",on ="년월")
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_12732\1466163675.py:7: FutureWarning: Passing 'suffixes' which cause duplicate columns {'건수지표_x'} in the result is deprecated and will raise a MergeError in a future version.
#   comp = comp.merge(right = travel, how ="inner",on ="년월")
#          건수지표_x   건수지표_y  건수지표_x  건수지표_y   건수지표_x    건수지표_y   건수지표_x   건수지표_y  \
# 년월
# 202001  3415733  4478468  258206  230706  1019873   9591687  1585412  5122111
# 202002  2633432  3887498  195335  172087   653686   8468359  1473958  3981674
# 202003  2237898  3399251  150361  142816   502791   7711247  1186796  3249203
# 202004  2469443  3993066  146963  147510   513922   8637555  1633283  3526893
# 202005  3220102  4893050  137517  192898   783565   9520328  2558689  4299842
# 202006  2961004  5159316  144530  154846   772510   9471168  3666187  4170136
# 202007  2959115  5313196  191809  183622   881355  10021681  2786087  4389458
# 202008  3068609  5633884  158142  141733  1221281   9262442  1944676  4418427
# 202009  2710010  4860469   72963   58738   706064   9931607  2304682  3843086
# 202010  2900688  5987054  133007  128700   959596   9358726  3696809  5064825
# 202011  2883224  5475720  169625  163838   892687   9325205  3871406  5085720
# 202012  2503535  4282809   28220   25770   769997   9080722  3066225  3202751
#
#            건수지표
# 년월
# 202001  6100581
# 202002  3861450
# 202003  2768523
# 202004  3095370
# 202005  6123941
# 202006  4370625
# 202007  4731112
# 202008  5765694
# 202009  3151717
# 202010  6175058
# 202011  4872447
# 202012  2516013

# %%
comp.columns = ["보건/위생","일반음식","유흥주점(음식)","단란주점(음식)","숙박업","의료기관","사무/통신기기","여행업","문화/취미"]
comp
# Out:
#           보건/위생     일반음식  유흥주점(음식)  단란주점(음식)      숙박업      의료기관  사무/통신기기  \
# 년월
# 202001  3415733  4478468    258206    230706  1019873   9591687  1585412
# 202002  2633432  3887498    195335    172087   653686   8468359  1473958
# 202003  2237898  3399251    150361    142816   502791   7711247  1186796
# 202004  2469443  3993066    146963    147510   513922   8637555  1633283
# 202005  3220102  4893050    137517    192898   783565   9520328  2558689
# 202006  2961004  5159316    144530    154846   772510   9471168  3666187
# 202007  2959115  5313196    191809    183622   881355  10021681  2786087
# 202008  3068609  5633884    158142    141733  1221281   9262442  1944676
# 202009  2710010  4860469     72963     58738   706064   9931607  2304682
# 202010  2900688  5987054    133007    128700   959596   9358726  3696809
# 202011  2883224  5475720    169625    163838   892687   9325205  3871406
# 202012  2503535  4282809     28220     25770   769997   9080722  3066225
#
#             여행업    문화/취미
# 년월
# 202001  5122111  6100581
# 202002  3981674  3861450
# 202003  3249203  2768523
# 202004  3526893  3095370
# 202005  4299842  6123941
# 202006  4170136  4370625
# 202007  4389458  4731112
# 202008  4418427  5765694
# 202009  3843086  3151717
# 202010  5064825  6175058
# 202011  5085720  4872447
# 202012  3202751  2516013

# %%
comp = pd.merge(left=clean, right = food, how ="inner",on ="년월")
comp = comp.merge(right = wine, how ="inner",on ="년월")
comp = comp.merge(right = wine_2, how ="inner",on ="년월")
comp = comp.merge(right = house, how ="inner",on ="년월")
comp = comp.merge(right = hospital, how ="inner",on ="년월")
comp = comp.merge(right = tel, how ="inner",on ="년월")
comp = comp.merge(right = travel, how ="inner",on ="년월")
comp = comp.merge(right = hob, how ="inner",on ="년월")
comp 
##2021년 코드 _ 결과가 다르게 나와야하지만 한 곳에 합쳤기에 2020년도와 같은 결과가 나올 것이다. 연도별 코드는 따로 게시할 예정이다

# %%
comp = pd.merge(left=clean, right = food, how ="inner",on ="년월")
comp = comp.merge(right = wine, how ="inner",on ="년월")
comp = comp.merge(right = wine_2, how ="inner",on ="년월")
comp = comp.merge(right = house, how ="inner",on ="년월")
comp = comp.merge(right = hospital, how ="inner",on ="년월")
comp = comp.merge(right = tel, how ="inner",on ="년월")
comp = comp.merge(right = travel, how ="inner",on ="년월")
comp = comp.merge(right = hob, how ="inner",on ="년월")
comp

#2022년도 코드

# %%
comp.columns = ["보건/위생","일반음식","유흥주점(음식)","단란주점(음식)","숙박업","의료기관","사무/통신기기","여행업","문화/취미"]
comp

#만들어진 변수 컬럼명을 새로 지어준다.

# %%
comp.plot(linewidth =3.0)
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
plt.show()     ##1.0 은 천만 / 0.8은 8백만이다

#2020년도의 소비 변화를 나타낸 그래프이다.

# %% [markdown]
# #행렬이 바뀐 데이터를 만들어주었다. 파이 차트를 통하여 분야별 소비를 알아보기 위해서 한 것인데, 확진자 수가 많고 적은 월 별끼리 비교를 하는 것이 옳다고 판단하여 행렬을 바꾸어 데이터를 새로 만들어주었다

# %%
comp_t =comp.transpose()

# %%
comp_t
# Out:
# 년월         202001   202002   202003   202004   202005   202006    202007  \
# 보건/위생     3415733  2633432  2237898  2469443  3220102  2961004   2959115
# 일반음식      4478468  3887498  3399251  3993066  4893050  5159316   5313196
# 유흥주점(음식)   258206   195335   150361   146963   137517   144530    191809
# 단란주점(음식)   230706   172087   142816   147510   192898   154846    183622
# 숙박업       1019873   653686   502791   513922   783565   772510    881355
# 의료기관      9591687  8468359  7711247  8637555  9520328  9471168  10021681
# 사무/통신기기   1585412  1473958  1186796  1633283  2558689  3666187   2786087
# 여행업       5122111  3981674  3249203  3526893  4299842  4170136   4389458
# 문화/취미     6100581  3861450  2768523  3095370  6123941  4370625   4731112
#
# 년월         202008   202009   202010   202011   202012
# 보건/위생     3068609  2710010  2900688  2883224  2503535
# 일반음식      5633884  4860469  5987054  5475720  4282809
# 유흥주점(음식)   158142    72963   133007   169625    28220
# 단란주점(음식)   141733    58738   128700   163838    25770
# 숙박업       1221281   706064   959596   892687   769997
# 의료기관      9262442  9931607  9358726  9325205  9080722
# 사무/통신기기   1944676  2304682  3696809  3871406  3066225
# 여행업       4418427  3843086  5064825  5085720  3202751
# 문화/취미     5765694  3151717  6175058  4872447  2516013

# %%
Jan = comp_t[202001] #행렬이 바뀐 comp데이터 : comp_t중에서 1월달 정보를 Jan이라는 변수로 할당

# %%
labels = ["보건/위생","일반음식","유흥주점(음식)","단란주점(음식)","숙박업","의료기관","사무/통신기기","여행업","문화/취미"]

# %% [markdown]
# #### Section 2.2 <a class="anchor" id="section_2_2"></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
Jan.plot.pie(autopct='%.1f%%')
plt.title("2020년 1월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Mar = comp_t[202003]
Mar.plot.pie(autopct='%.1f%%')
plt.title("2020년 3월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Aug = comp_t[202008]
Aug.plot.pie(autopct='%.1f%%')
plt.title("2020년 8월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Oct = comp_t[202010]
Oct.plot.pie(autopct='%.1f%%')
plt.title("2020년 10월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Nov = comp_t[202011]
Nov.plot.pie(autopct='%.1f%%')
plt.title("2020년 11월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Dec = comp_t[202012]
Dec.plot.pie(autopct='%.1f%%') 
plt.title("2020년 12월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))
