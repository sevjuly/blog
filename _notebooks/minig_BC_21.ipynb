# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import seaborn as sns

# %%
year_2021.shape
# Out:
# (1062906, 4)

# %%
ab =  pd.read_csv('data_bc/2021_01.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
bc =  pd.read_csv('data_bc/2021_02.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
cd =  pd.read_csv('data_bc/2021_03.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
de =  pd.read_csv('data_bc/2021_04.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
ef =  pd.read_csv('data_bc/2021_05.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
fg =  pd.read_csv('data_bc/2021_06.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
gh =  pd.read_csv('data_bc/2021_07.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
hi =  pd.read_csv('data_bc/2021_08.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
ij =  pd.read_csv('data_bc/2021_09.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
ik =  pd.read_csv('data_bc/2021_10.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
kl =  pd.read_csv('data_bc/2021_11.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
lm =  pd.read_csv('data_bc/2021_12.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
year_2021 = pd.concat([ ab,bc,cd,de,ef,fg,gh,hi,ij,ik,kl,lm])
# Out:
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_1492\2539148643.py:10: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   ik =  pd.read_csv('data_bc/2021_10.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_1492\2539148643.py:11: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   kl =  pd.read_csv('data_bc/2021_11.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_1492\2539148643.py:12: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   lm =  pd.read_csv('data_bc/2021_12.csv', sep ='^',names=["년월","대분류","소분류","나이대","성별코드","지역","지역_2","금액지표","건수지표"])

# %%
year_2021.head()
# Out:
#        년월    대분류    소분류 나이대  성별코드  지역 지역_2  금액지표  건수지표
# 0  202101  보건/위생  화 장 품  70     1  강원  강릉시    99    68
# 1  202101  보건/위생  의료 용품  30     1  강원  강릉시   130   121
# 2  202101  보건/위생  의료 용품  40     1  강원  강릉시   446   169
# 3  202101  보건/위생    사우나  30     2  강원  강릉시    16    16
# 4  202101  보건/위생    사우나  60     2  강원  강릉시    37    51

# %%
year_2021.tail()
# Out:
#             년월 대분류    소분류 나이대  성별코드  지역 지역_2  금액지표  건수지표
# 290956  202112  기타  기계 공구  60     1  충북  충주시    94    84
# 290957  202112  기타  비 영 리  40     2  충북  충주시   151   273
# 290958  202112  기타  기타전문점  20     1  충북  충주시   461   750
# 290959  202112  기타  기타전문점  50     1  충북  충주시    33    86
# 290960  202112  기타  기타전문점  60     1  충북  충주시    78    74

# %%
year_2021 =year_2021[(year_2021["대분류"]=="일반음식") | (year_2021["대분류"]=="유흥주점(음식)") | (year_2021["대분류"]=="단란주점(음식)") | (year_2021["대분류"]=="숙박업")|(year_2021["대분류"]=="여행업")| (year_2021["대분류"]=="문화/취미") | (year_2021["대분류"]=="사무/통신기기")| (year_2021["대분류"]=="보건/위생") | (year_2021["대분류"]=="의료기관") | (year_2021["대분류"]=="보험")]

# %%
year_2021["대분류"].unique()
# Out:
# array(['보건/위생', '일반음식', '숙박업', '의료기관', '사무/통신기기', '문화/취미', '여행업', '보험',
#        '유흥주점(음식)', '단란주점(음식)'], dtype=object)

# %%
year_2021 = year_2021.drop(["소분류","지역","지역_2","성별코드","나이대"],axis=1)

# %%
year_2021
# Out:
#             년월    대분류  금액지표  건수지표
# 0       202101  보건/위생    99    68
# 1       202101  보건/위생   130   121
# 2       202101  보건/위생   446   169
# 3       202101  보건/위생    16    16
# 4       202101  보건/위생    37    51
# ...        ...    ...   ...   ...
# 290910  202112   일반음식  1502  1116
# 290911  202112   일반음식   112   106
# 290912  202112   일반음식   202   106
# 290920  202112   일반음식   137   199
# 290921  202112   일반음식    66    97
#
# [1062906 rows x 4 columns]

# %% [markdown]
# ## 종류별 그래프

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
a= year_2021[year_2021['대분류']=='보건/위생']

clean= a.groupby('년월')['건수지표'].sum()
clean

clean.plot(color ="red",linewidth =3.0)
plt.ylim(2200000, 3400000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("보건/위생")
plt.show()

# %%
b= year_2021[year_2021['대분류']=='일반음식']
b

food= b.groupby('년월')['건수지표'].sum()
food.plot(color ="orange",linewidth =3.0)
plt.ylim(3000000,7000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("일반음식")
plt.show()

# %%
c= year_2021[year_2021['대분류']=='유흥주점(음식)']
wine= c.groupby('년월')['건수지표'].sum()
wine.plot(color ="yellow",linewidth =3.0)
plt.ylim(0,260000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("유흥주점(음식)")
plt.show()

# %%
d= year_2021[year_2021['대분류']=='단란주점(음식)']
wine_2= d.groupby('년월')['건수지표'].sum()
wine_2.plot(color ="yellowgreen",linewidth =3.0)
plt.ylim(0, 250000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("단란주점(음식)")
plt.show()

# %%
e = year_2021[year_2021['대분류']=='숙박업']

house = e.groupby('년월')['건수지표'].sum()
house.plot(color ="darkgreen",linewidth =3.0)
plt.ylim(50000, 1300000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("숙박업")
plt.show()

# %%
f= year_2021[year_2021['대분류']=='의료기관']

hospital = f.groupby('년월')['건수지표'].sum()
hospital.plot(color ="skyblue",linewidth =3.0)
plt.ylim(7000000,10500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("의료기관")
plt.show()

# %%
g = year_2021[year_2021['대분류']=='사무/통신기기']

tel = g.groupby('년월')['건수지표'].sum()
tel.plot(color ="darkblue",linewidth =3.0)
plt.ylim(1000000,5000000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("사무/통신기기")
plt.show()

# %%
h = year_2021[year_2021['대분류']=='여행업']

travel = h.groupby('년월')['건수지표'].sum()
travel.plot(color ="purple",linewidth =3.0)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("여행업")
plt.show()

# %%
i = year_2021[year_2021['대분류']=='문화/취미']

hob = i.groupby('년월')['건수지표'].sum()
hob.plot(color ="pink",linewidth =3.0)
plt.ylim(2300000,8500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("문화/취미")
plt.show()

# %%
j = year_2021[year_2021['대분류']=='보험']

bo = j.groupby('년월')['건수지표'].sum()
bo.plot(color ="gray",linewidth =3.0)
plt.ylim(7250000,9500000)
plt.ticklabel_format(style ='plain')
plt.xlabel("년도_월")
plt.ylabel("월별 건수 합")
plt.title("보험")
plt.show()

# %%
comp = pd.merge(left=clean, right = food, how ="inner",on ="년월")
comp = comp.merge(right = wine, how ="inner",on ="년월")
comp = comp.merge(right = wine_2, how ="inner",on ="년월")
comp = comp.merge(right = house, how ="inner",on ="년월")
comp = comp.merge(right = hospital, how ="inner",on ="년월")
comp = comp.merge(right = tel, how ="inner",on ="년월")
comp = comp.merge(right = travel, how ="inner",on ="년월")
comp = comp.merge(right = hob, how ="inner",on ="년월")
comp
# Out:
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_1492\1105633761.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'건수지표_x'} in the result is deprecated and will raise a MergeError in a future version.
#   comp = comp.merge(right = wine_2, how ="inner",on ="년월")
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_1492\1105633761.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'건수지표_x'} in the result is deprecated and will raise a MergeError in a future version.
#   comp = comp.merge(right = hospital, how ="inner",on ="년월")
# C:\Users\Parksunmin\AppData\Local\Temp\ipykernel_1492\1105633761.py:7: FutureWarning: Passing 'suffixes' which cause duplicate columns {'건수지표_x'} in the result is deprecated and will raise a MergeError in a future version.
#   comp = comp.merge(right = travel, how ="inner",on ="년월")
#          건수지표_x   건수지표_y  건수지표_x  건수지표_y   건수지표_x    건수지표_y   건수지표_x   건수지표_y  \
# 년월
# ...

# %%
comp.columns = ["보건/위생","일반음식","유흥주점(음식)","단란주점(음식)","숙박업","의료기관","사무/통신기기","여행업","문화/취미"]
comp
# Out:
#           보건/위생     일반음식  유흥주점(음식)  단란주점(음식)      숙박업      의료기관  사무/통신기기  \
# 년월
# 202101  2434638  3755923       306       131   603693   8483818  1633023
# 202102  2458657  4132163     16928     19224   668658   7891761  1505449
# 202103  2967067  5397724     90232    100665   715238   9520476  3282088
# 202104  2883034  5521784     88985     79390   756246   9712684  4060244
# 202105  3091242  5927220     90452     74584   919464   9193400  3525942
# 202106  2960972  5703526     95266     84208   853866   9884653  4386368
# 202107  2983426  5837673     76482     64205   980114   9977022  2754014
# 202108  2860439  5828163     33080     24114  1149044   9282285  2573268
# 202109  3098437  5937067     48099     42550   879540   9295286  3556097
# 202110  3320094  6698825     61791     55421  1024803  10465281  4805997
# 202111  3207814  6210598    116863    144525   966534   9958756  4755309
# 202112  3105472  6038946     75267     94288   975195  10154180  3851879
#
# ...

# %%
comp_t =comp.transpose()
comp_t
# Out:
# 년월         202101   202102   202103   202104   202105   202106   202107  \
# 보건/위생     2434638  2458657  2967067  2883034  3091242  2960972  2983426
# 일반음식      3755923  4132163  5397724  5521784  5927220  5703526  5837673
# 유흥주점(음식)      306    16928    90232    88985    90452    95266    76482
# 단란주점(음식)      131    19224   100665    79390    74584    84208    64205
# 숙박업        603693   668658   715238   756246   919464   853866   980114
# 의료기관      8483818  7891761  9520476  9712684  9193400  9884653  9977022
# 사무/통신기기   1633023  1505449  3282088  4060244  3525942  4386368  2754014
# 여행업       2998817  3288746  4439192  4409482  4622381  4499022  3999754
# 문화/취미     2376956  3762799  4568692  5221733  7736254  5733695  5095839
#
# 년월         202108   202109    202110   202111    202112
# 보건/위생     2860439  3098437   3320094  3207814   3105472
# 일반음식      5828163  5937067   6698825  6210598   6038946
# 유흥주점(음식)    33080    48099     61791   116863     75267
# ...

# %%
comp.plot(linewidth =3.0)  #범례 위치 변경하기
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
plt.show()     ##1.0 은 천만 / 0.8은 8백만이다

# %% [markdown]
# # 원 그래프

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
comp_t =comp.transpose()
comp_t
# Out:
# 년월         202101   202102   202103   202104   202105   202106   202107  \
# 보건/위생     2434638  2458657  2967067  2883034  3091242  2960972  2983426
# 일반음식      3755923  4132163  5397724  5521784  5927220  5703526  5837673
# 유흥주점(음식)      306    16928    90232    88985    90452    95266    76482
# 단란주점(음식)      131    19224   100665    79390    74584    84208    64205
# 숙박업        603693   668658   715238   756246   919464   853866   980114
# 의료기관      8483818  7891761  9520476  9712684  9193400  9884653  9977022
# 사무/통신기기   1633023  1505449  3282088  4060244  3525942  4386368  2754014
# 여행업       2998817  3288746  4439192  4409482  4622381  4499022  3999754
# 문화/취미     2376956  3762799  4568692  5221733  7736254  5733695  5095839
#
# 년월         202108   202109    202110   202111    202112
# 보건/위생     2860439  3098437   3320094  3207814   3105472
# 일반음식      5828163  5937067   6698825  6210598   6038946
# 유흥주점(음식)    33080    48099     61791   116863     75267
# ...

# %%
labels = ["보건/위생","일반음식","유흥주점(음식)","단란주점(음식)","숙박업","의료기관","사무/통신기기","여행업","문화/취미"]

# %%
Feb = comp_t[202102]
Feb.plot.pie(autopct='%.1f%%')
plt.title("2021년 2월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Aug = comp_t[202108]
Aug.plot.pie(autopct='%.1f%%')
plt.title("2021년 8월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Sep = comp_t[202109]
Sep.plot.pie(autopct='%.1f%%')
plt.title("2021년 9월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))

# %%
Oct= comp_t[202110]
Oct.plot.pie(autopct='%.1f%%')
plt.title("2021년 10월 분야별 구매건수")
plt.ylabel("")
plt.legend(labels,loc='center left',bbox_to_anchor=(1,0.5))
